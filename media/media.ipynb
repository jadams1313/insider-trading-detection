# %%
import pandas as pd 
import media_data as md 
import os
import zipfile
tickers = [
    "AMSC",   # American Superconductor
    "NP",     # Neenah Paper / Neenah Inc.
    "EVR",    # Evercore
    "GOOGL",  # Google (Alphabet Class A)
    "GTXI",   # GTx Inc.
    "HLF",    # Herbalife
    "MDRX",   # Veradigm (formerly Allscripts)
    "ORCL",   # Oracle
    "SPPI",   # Spectrum Pharmaceuticals
    "WFC"     # Wells Fargo
]

# %% [markdown]
# Read data

# %%
gkg_dir = "media_data/input/raw"
all_data = []

for fname in os.listdir(gkg_dir):
    if fname.endswith(".zip"):
        zip_path = os.path.join(gkg_dir, fname)
        print(f"Processing {fname}...")

        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            for file_in_zip in zip_ref.namelist():
                with zip_ref.open(file_in_zip) as f:
                    # Load only relevant columns
                    df = md.load_gkg_for_insider_trading(f)
                    if df is not None and not df.empty:
                        # Parse fields
                        df = md.parse_gkg_fields(df)
                        # Filter for insider trading relevance
                        df = md.filter_for_insider_trading(df)
                        if not df.empty:
                            # Filter for target companies
                            df = md.filter_by_companies(df, tickers)
                            if not df.empty:
                                all_data.append(df)
combined_df = pd.concat(all_data, ignore_index=True)
# Out:
# Processing 20150221173000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 334 potentially relevant articles
#   ✓ Filtered from 1,470 total articles (22.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    15 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150224070000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 561 potentially relevant articles
#   ✓ Filtered from 1,996 total articles (28.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150227143000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 786 potentially relevant articles
#   ✓ Filtered from 2,961 total articles (26.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     3 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     1 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150301133000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 271 potentially relevant articles
#   ✓ Filtered from 1,581 total articles (17.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150304110000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 578 potentially relevant articles
#   ✓ Filtered from 2,335 total articles (24.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     5 articles
# Processing 20150306164500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 876 potentially relevant articles
#   ✓ Filtered from 3,181 total articles (27.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     8 articles
# Processing 20150308154500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 428 potentially relevant articles
#   ✓ Filtered from 1,586 total articles (27.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     2 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150310061500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 495 potentially relevant articles
#   ✓ Filtered from 1,978 total articles (25.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150314091500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 344 potentially relevant articles
#   ✓ Filtered from 1,406 total articles (24.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150317204500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 916 potentially relevant articles
#   ✓ Filtered from 3,420 total articles (26.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    13 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):    11 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150318221500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,024 potentially relevant articles
#   ✓ Filtered from 3,480 total articles (29.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    22 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150321011500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 525 potentially relevant articles
#   ✓ Filtered from 2,008 total articles (26.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150326150000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,007 potentially relevant articles
#   ✓ Filtered from 3,566 total articles (28.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    27 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150329123000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 285 potentially relevant articles
#   ✓ Filtered from 1,185 total articles (24.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150401070000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 584 potentially relevant articles
#   ✓ Filtered from 2,100 total articles (27.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     1 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150402050000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 637 potentially relevant articles
#   ✓ Filtered from 2,317 total articles (27.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150405173000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 361 potentially relevant articles
#   ✓ Filtered from 1,619 total articles (22.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150407101500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 556 potentially relevant articles
#   ✓ Filtered from 2,217 total articles (25.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    18 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150411004500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 525 potentially relevant articles
#   ✓ Filtered from 2,024 total articles (25.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150413201500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 642 potentially relevant articles
#   ✓ Filtered from 2,733 total articles (23.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     9 articles
# Processing 20150418064500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 290 potentially relevant articles
#   ✓ Filtered from 1,317 total articles (22.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150421144500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 859 potentially relevant articles
#   ✓ Filtered from 3,108 total articles (27.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    43 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150424190000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 678 potentially relevant articles
#   ✓ Filtered from 2,755 total articles (24.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    27 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150428094500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 893 potentially relevant articles
#   ✓ Filtered from 3,201 total articles (27.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    15 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150502201500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 319 potentially relevant articles
#   ✓ Filtered from 1,236 total articles (25.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     3 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     9 articles
# Processing 20150505233000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 844 potentially relevant articles
#   ✓ Filtered from 2,729 total articles (30.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    13 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     4 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):    10 articles
# Processing 20150510163000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 458 potentially relevant articles
#   ✓ Filtered from 1,851 total articles (24.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     0 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150519070000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 515 potentially relevant articles
#   ✓ Filtered from 1,918 total articles (26.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150521114500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 768 potentially relevant articles
#   ✓ Filtered from 2,897 total articles (26.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     2 articles
#   GOOGL  (Google                        ):    18 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     4 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150523113000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 361 potentially relevant articles
#   ✓ Filtered from 1,648 total articles (21.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150527041500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 477 potentially relevant articles
#   ✓ Filtered from 1,922 total articles (24.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     4 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150601021500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 356 potentially relevant articles
#   ✓ Filtered from 1,819 total articles (19.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     1 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150602150000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 917 potentially relevant articles
#   ✓ Filtered from 3,231 total articles (28.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    19 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150606200000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 303 potentially relevant articles
#   ✓ Filtered from 1,389 total articles (21.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     3 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150608154500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 877 potentially relevant articles
#   ✓ Filtered from 3,359 total articles (26.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    16 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150616140000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 919 potentially relevant articles
#   ✓ Filtered from 3,345 total articles (27.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    21 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150619220000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 572 potentially relevant articles
#   ✓ Filtered from 2,545 total articles (22.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    10 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150625184500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 838 potentially relevant articles
#   ✓ Filtered from 3,591 total articles (23.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):    14 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     4 articles
# Processing 20150629003000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 394 potentially relevant articles
#   ✓ Filtered from 1,702 total articles (23.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150701234500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 688 potentially relevant articles
#   ✓ Filtered from 2,795 total articles (24.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    16 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150703081500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 526 potentially relevant articles
#   ✓ Filtered from 2,150 total articles (24.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150712054500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 397 potentially relevant articles
#   ✓ Filtered from 1,672 total articles (23.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     1 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150715101500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 732 potentially relevant articles
#   ✓ Filtered from 3,243 total articles (22.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150716094500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 800 potentially relevant articles
#   ✓ Filtered from 3,054 total articles (26.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    15 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150717084500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 687 potentially relevant articles
#   ✓ Filtered from 2,632 total articles (26.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    16 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150728134500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 774 potentially relevant articles
#   ✓ Filtered from 2,966 total articles (26.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    22 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150731171500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 872 potentially relevant articles
#   ✓ Filtered from 3,710 total articles (23.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    21 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     5 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     6 articles
# Processing 20150801200000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 405 potentially relevant articles
#   ✓ Filtered from 1,722 total articles (23.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150804130000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 796 potentially relevant articles
#   ✓ Filtered from 3,017 total articles (26.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     1 articles
#   GOOGL  (Google                        ):    18 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     7 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150805221500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,030 potentially relevant articles
#   ✓ Filtered from 3,538 total articles (29.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    15 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     6 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150811193000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,083 potentially relevant articles
#   ✓ Filtered from 4,150 total articles (26.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    26 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     4 articles
# Processing 20150816064500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 377 potentially relevant articles
#   ✓ Filtered from 1,528 total articles (24.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     2 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150817211500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 809 potentially relevant articles
#   ✓ Filtered from 3,235 total articles (25.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    10 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     4 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150819054500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 668 potentially relevant articles
#   ✓ Filtered from 2,757 total articles (24.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150821014500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 635 potentially relevant articles
#   ✓ Filtered from 2,465 total articles (25.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    10 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150823073000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 359 potentially relevant articles
#   ✓ Filtered from 1,696 total articles (21.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150826051500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 622 potentially relevant articles
#   ✓ Filtered from 2,618 total articles (23.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150831060000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 501 potentially relevant articles
#   ✓ Filtered from 2,197 total articles (22.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150901174500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 954 potentially relevant articles
#   ✓ Filtered from 3,829 total articles (24.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    22 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150903091500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 765 potentially relevant articles
#   ✓ Filtered from 2,973 total articles (25.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     4 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150905143000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 374 potentially relevant articles
#   ✓ Filtered from 1,852 total articles (20.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150906161500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 292 potentially relevant articles
#   ✓ Filtered from 1,380 total articles (21.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150909180000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 921 potentially relevant articles
#   ✓ Filtered from 3,952 total articles (23.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    26 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     8 articles
# Processing 20150915141500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 914 potentially relevant articles
#   ✓ Filtered from 3,325 total articles (27.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
# ...
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20171107103000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 587 potentially relevant articles
#   ✓ Filtered from 2,294 total articles (25.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     1 articles
#   GOOGL  (Google                        ):    13 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20171109154500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,016 potentially relevant articles
#   ✓ Filtered from 3,645 total articles (27.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    19 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20171111144500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 376 potentially relevant articles
#   ✓ Filtered from 1,643 total articles (22.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     1 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20171114044500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 529 potentially relevant articles
#   ✓ Filtered from 2,078 total articles (25.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     3 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20171117121500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 559 potentially relevant articles
#   ✓ Filtered from 2,387 total articles (23.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    10 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20171120163000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 993 potentially relevant articles
#   ✓ Filtered from 3,973 total articles (25.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     5 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     1 articles
#   WFC    (Wells Fargo                   ):     4 articles
# Processing 20171121203000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,035 potentially relevant articles
#   ✓ Filtered from 4,191 total articles (24.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    43 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     5 articles
# Processing 20171123014500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 622 potentially relevant articles
#   ✓ Filtered from 2,534 total articles (24.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    14 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20171201004500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 738 potentially relevant articles
#   ✓ Filtered from 3,299 total articles (22.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20171201234500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 868 potentially relevant articles
#   ✓ Filtered from 3,039 total articles (28.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     1 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):    13 articles
# Processing 20171205063000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 609 potentially relevant articles
#   ✓ Filtered from 2,399 total articles (25.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    10 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20171208113000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 673 potentially relevant articles
#   ✓ Filtered from 2,447 total articles (27.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     6 articles
# Processing 20171212023000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 586 potentially relevant articles
#   ✓ Filtered from 2,372 total articles (24.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     3 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20171216114500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 235 potentially relevant articles
#   ✓ Filtered from 1,254 total articles (18.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     4 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     6 articles
# Processing 20171218121500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 611 potentially relevant articles
#   ✓ Filtered from 2,343 total articles (26.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     1 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     5 articles
# Processing 20171219171500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 995 potentially relevant articles
#   ✓ Filtered from 3,936 total articles (25.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    28 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20171221211500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 923 potentially relevant articles
#   ✓ Filtered from 3,505 total articles (26.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     9 articles
# Processing 20171224230000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 325 potentially relevant articles
#   ✓ Filtered from 1,475 total articles (22.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     2 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20171226140000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 487 potentially relevant articles
#   ✓ Filtered from 2,125 total articles (22.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     4 articles
# Processing 20171229234500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 435 potentially relevant articles
#   ✓ Filtered from 1,898 total articles (22.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    15 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20171230003000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 538 potentially relevant articles
#   ✓ Filtered from 2,485 total articles (21.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    25 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles

# %% [markdown]
# Read in Columns

# %%
combined_df.columns
combined_df.head()
# Out:
#           GKGRECORDID            DATE  SourceCommonName  \
# 0  20150221173000-188  20150221173000  newspressnow.com
# 1  20150221173000-262  20150221173000   venturebeat.com
# 2  20150221173000-283  20150221173000            al.com
# 3  20150221173000-297  20150221173000          fark.com
# 4  20150221173000-300  20150221173000  theworldlink.com
#
#                                   DocumentIdentifier  \
# 0  http://www.newspressnow.com/news/politics/ap/a...
# 1  http://venturebeat.com/2015/02/21/airtame-want...
# 2  http://www.al.com/news/index.ssf/2015/02/democ...
# 3  http://www.fark.com/comments/8607263/Elderly-N...
# 4  http://theworldlink.com/news/national/govt-and...
#
#                                               Themes  \
# 0  TAX_POLITICAL_PARTY;TAX_POLITICAL_PARTY_DEMOCR...
# 1  MEDIA_MSM;ECON_WORLDCURRENCIES;ECON_WORLDCURRE...
# 2  TAX_POLITICAL_PARTY;TAX_POLITICAL_PARTY_DEMOCR...
# 3  CRIME_ILLEGAL_DRUGS;DRUG_TRADE;TAX_FNCACT;TAX_...
# 4  TAX_POLITICAL_PARTY;TAX_POLITICAL_PARTY_DEMOCR...
#
#                                              Persons  \
# 0  eric schmidt;dan malloy;wasserman schultz;j pa...
# 1                   jonas gyalokay;google chromecast
# 2  eric schmidt;dan malloy;wasserman schultz;bara...
# 3                                           lou reed
# 4  eric schmidt;dan malloy;wasserman schultz;bara...
#
#                                        Organizations  \
# 0  google;supreme court;democratic national commi...
# 1                   google;youtube;netflix;microsoft
# 2  google;supreme court;senate to republicans;dem...
# 3                                                NaN
# 4  google;supreme court;senate to republicans;dem...
#
#                                               V2Tone  \
# 0  2.00250312891114,4.8811013767209,2.87859824780...
# 1  0.72595281306715,2.63157894736842,1.9056261343...
# 2  2.01863354037267,4.81366459627329,2.7950310559...
# 3  -2.50756593169045,1.98875918720277,4.496325118...
# 4  1.94610778443114,4.64071856287425,2.6946107784...
#
#                                                 GCAM  \
# 0  wc:721,c1.2:1,c1.4:1,c12.1:48,c12.10:70,c12.12...
# 1  wc:983,c1.3:2,c12.1:58,c12.10:103,c12.11:1,c12...
# 2  wc:595,c1.4:1,c12.1:39,c12.10:56,c12.12:18,c12...
# 3  wc:2095,c12.1:195,c12.10:228,c12.12:88,c12.13:...
# 4  wc:604,c1.4:1,c12.1:39,c12.10:56,c12.12:18,c12...
#
#                                           Quotations  ... Month   Day  Hour  \
# 0                                                NaN  ...   2.0  21.0  17.0
# 1                                                NaN  ...   2.0  21.0  17.0
# 2                                                NaN  ...   2.0  21.0  17.0
# 3  2152|33||not many people asked me about it#261...  ...   2.0  21.0  17.0
# 4                                                NaN  ...   2.0  21.0  17.0
#
#    OrgCount  PrimaryOrg  PersonCount   PrimaryPerson HasFinancialTheme Ticker  \
# 0         5      google            7    eric schmidt              True  GOOGL
# 1         4      google            2  jonas gyalokay              True  GOOGL
# 2         4      google            6    eric schmidt              True  GOOGL
# 3         0         NaN            1        lou reed              True  GOOGL
# 4         4      google            6    eric schmidt              True  GOOGL
#
#    CompanyName
# 0       Google
# 1       Google
# 2       Google
# 3       Google
# 4       Google
#
# [5 rows x 30 columns]

# %% [markdown]
# Filter

# %% [markdown]
# Analyze

# %%
combined_df = md.analyze_company_coverage(combined_df)
ts = md.create_company_timeseries(combined_df)
print("\n" + "="*60)
print("✓ FILTERING COMPLETE!")
print("="*60)
print(f"\nDataFrames available:")
print(f"  - df: Full GKG data ({len(df):,} rows)")
print(f"  - df_companies: Filtered company data ({len(combined_df):,} rows)")
print(f"  - ts: Time series by company-date ({len(ts):,} rows)")
# Out:
#       Date Ticker CompanyName       Tone  Polarity        SourceCommonName
# 2016-06-07   ORCL      Oracle  -7.086614 14.960630             reuters.com
# 2015-06-08  GOOGL      Google -13.793103 14.942529 princegeorgecitizen.com
# 2015-08-31  GOOGL      Google -13.225806 14.516129        clickorlando.com
# 2016-12-17  GOOGL      Google   0.961538 14.423077     contacto-latino.com
# 2015-10-07  GOOGL      Google  12.121212 14.141414            watchpro.com
# 2015-08-31  GOOGL      Google -12.852665 14.106583    siouxlandmatters.com
# 2015-12-15  GOOGL      Google  -9.246575 14.041096            ghanaweb.com
# 2015-08-31  GOOGL      Google -12.500000 13.928571              kotatv.com
# 2015-08-31  GOOGL      Google -12.500000 13.928571         channel3000.com
# 2017-06-05  GOOGL      Google  -9.349593 13.617886                wtsp.com
#
# ============================================================
# TIME SERIES DATA
# ============================================================
# ✓ Created time series with 786 date-company pairs
#
# Sample:
#          Date Ticker  ArticleCount      Tone  Polarity  WordCount
# 0  2015-02-21  GOOGL            15  1.127070  6.239087   0.883171
# 1  2015-02-24  GOOGL             8  0.451390  4.964659   0.745560
# 2  2015-02-24    WFC             1 -4.334365  6.501548   0.464396
# 3  2015-02-27    EVR             3 -1.264141  5.413669   2.626162
# 4  2015-02-27  GOOGL            11 -0.728092  5.214361   1.117178
# 5  2015-02-27   SPPI             1  0.863931  2.159827   0.000000
# 6  2015-03-01  GOOGL             7 -0.496590  4.340214   0.782226
# 7  2015-03-01   ORCL             2  1.674798  5.789514   0.206768
# 8  2015-03-01    WFC             1  1.944895  3.241491   0.486224
# 9  2015-03-04  GOOGL             9 -1.703651  5.543984   0.492159
#
# ============================================================
# ✓ FILTERING COMPLETE!
# ============================================================
#
# DataFrames available:
#   - df: Full GKG data (26 rows)
#   - df_companies: Filtered company data (5,551 rows)
#   - ts: Time series by company-date (786 rows)

# %% [markdown]
# Save for future use

# %%
combined_df.to_csv('media_data/gkg_filtered_companies.csv', index=False)
ts.to_csv('media_data/gkg_company_timeseries.csv', index=False)
print(f"\n✓ Saved filtered data to CSV files")
# Out:
# ✓ Saved filtered data to CSV files
