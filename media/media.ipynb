# %%
import pandas as pd 
import media_transform_load as md 
import os
import zipfile
tickers = [
    "AMSC",   # American Superconductor
    "NP",     # Neenah Paper / Neenah Inc.
    "EVR",    # Evercore
    "GOOGL",  # Google (Alphabet Class A)
    "GTXI",   # GTx Inc.
    "HLF",    # Herbalife
    "MDRX",   # Veradigm (formerly Allscripts)
    "ORCL",   # Oracle
    "SPPI",   # Spectrum Pharmaceuticals
    "WFC"     # Wells Fargo
]

# %% [markdown]
# Read data

# %%
gkg_dir = "media_data/input/raw"
all_data = []

for fname in os.listdir(gkg_dir):
    if fname.endswith(".zip"):
        zip_path = os.path.join(gkg_dir, fname)
        print(f"Processing {fname}...")

        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            for file_in_zip in zip_ref.namelist():
                with zip_ref.open(file_in_zip) as f:
                    # Load only relevant columns
                    df = md.load_gkg_for_insider_trading(f)
                    if df is not None and not df.empty:
                        # Parse fields
                        df = md.parse_gkg_fields(df)
                        # Filter for insider trading relevance
                        df = md.filter_for_insider_trading(df)
                        if not df.empty:
                            # Filter for target companies
                            df = md.filter_by_companies(df, tickers)
                            if not df.empty:
                                all_data.append(df)
combined_df = pd.concat(all_data, ignore_index=True)
# Out:
# Processing 20150219144500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 937 potentially relevant articles
#   ✓ Filtered from 3,618 total articles (25.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     1 articles
#   GOOGL  (Google                        ):    23 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150221201500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 284 potentially relevant articles
#   ✓ Filtered from 1,379 total articles (20.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    13 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150223034500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 416 potentially relevant articles
#   ✓ Filtered from 1,834 total articles (22.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     1 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150227143000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 786 potentially relevant articles
#   ✓ Filtered from 2,961 total articles (26.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     3 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     1 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150228201500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 278 potentially relevant articles
#   ✓ Filtered from 1,441 total articles (19.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     2 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     1 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150302143000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 978 potentially relevant articles
#   ✓ Filtered from 3,301 total articles (29.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    33 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     1 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     4 articles
# Processing 20150305164500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 970 potentially relevant articles
#   ✓ Filtered from 3,535 total articles (27.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    16 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150308063000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 407 potentially relevant articles
#   ✓ Filtered from 1,624 total articles (25.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     4 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150309004500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 473 potentially relevant articles
#   ✓ Filtered from 1,886 total articles (25.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150313090000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 617 potentially relevant articles
#   ✓ Filtered from 2,136 total articles (28.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    10 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150316064500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 463 potentially relevant articles
#   ✓ Filtered from 1,672 total articles (27.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150318151500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 975 potentially relevant articles
#   ✓ Filtered from 3,649 total articles (26.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    20 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     5 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     5 articles
# Processing 20150319070000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 519 potentially relevant articles
#   ✓ Filtered from 2,157 total articles (24.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150321051500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 379 potentially relevant articles
#   ✓ Filtered from 1,504 total articles (25.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     2 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150325150000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,024 potentially relevant articles
#   ✓ Filtered from 3,512 total articles (29.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    21 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150327060000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 542 potentially relevant articles
#   ✓ Filtered from 2,109 total articles (25.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150330084500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 440 potentially relevant articles
#   ✓ Filtered from 2,042 total articles (21.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150401054500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 578 potentially relevant articles
#   ✓ Filtered from 2,396 total articles (24.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     4 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150405003000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 321 potentially relevant articles
#   ✓ Filtered from 1,392 total articles (23.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150405103000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 251 potentially relevant articles
#   ✓ Filtered from 1,194 total articles (21.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150406210000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 658 potentially relevant articles
#   ✓ Filtered from 2,790 total articles (23.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150409220000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 713 potentially relevant articles
#   ✓ Filtered from 2,934 total articles (24.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    15 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150413060000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 337 potentially relevant articles
#   ✓ Filtered from 1,699 total articles (19.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150413070000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 451 potentially relevant articles
#   ✓ Filtered from 1,908 total articles (23.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150419030000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 281 potentially relevant articles
#   ✓ Filtered from 1,207 total articles (23.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     4 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150421153000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 998 potentially relevant articles
#   ✓ Filtered from 3,552 total articles (28.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    31 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     4 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150422180000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 865 potentially relevant articles
#   ✓ Filtered from 3,404 total articles (25.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    51 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150423020000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 679 potentially relevant articles
#   ✓ Filtered from 2,264 total articles (30.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    22 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150426190000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 367 potentially relevant articles
#   ✓ Filtered from 1,518 total articles (24.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150429053000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 712 potentially relevant articles
#   ✓ Filtered from 2,340 total articles (30.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150430103000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 903 potentially relevant articles
#   ✓ Filtered from 3,293 total articles (27.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    18 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150430200000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,009 potentially relevant articles
#   ✓ Filtered from 3,613 total articles (27.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     2 articles
#   ORCL   (Oracle                        ):     4 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150503223000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 323 potentially relevant articles
#   ✓ Filtered from 1,275 total articles (25.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150507194500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,023 potentially relevant articles
#   ✓ Filtered from 3,666 total articles (27.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    10 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     1 articles
#   MDRX   (Veradigm                      ):     1 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150509080000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 486 potentially relevant articles
#   ✓ Filtered from 1,673 total articles (29.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150510221500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 368 potentially relevant articles
#   ✓ Filtered from 1,514 total articles (24.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     0 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150514183000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 960 potentially relevant articles
#   ✓ Filtered from 3,436 total articles (27.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):    29 articles
# Processing 20150519020000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 601 potentially relevant articles
#   ✓ Filtered from 1,921 total articles (31.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150519110000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 851 potentially relevant articles
#   ✓ Filtered from 2,621 total articles (32.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    16 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150522021500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 549 potentially relevant articles
#   ✓ Filtered from 1,990 total articles (27.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150523000000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 484 potentially relevant articles
#   ✓ Filtered from 2,108 total articles (23.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150526203000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 0 potentially relevant articles
#   ✓ Filtered from 4 total articles (0.0%)
# Processing 20150529104500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 625 potentially relevant articles
#   ✓ Filtered from 2,612 total articles (23.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150601113000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 671 potentially relevant articles
#   ✓ Filtered from 2,766 total articles (24.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     4 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150602211500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 0 potentially relevant articles
#   ✓ Filtered from 1 total articles (0.0%)
# Processing 20150607144500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 429 potentially relevant articles
#   ✓ Filtered from 1,617 total articles (26.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     2 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150608221500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 901 potentially relevant articles
#   ✓ Filtered from 2,954 total articles (30.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    29 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     4 articles
# Processing 20150609221500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 792 potentially relevant articles
#   ✓ Filtered from 2,820 total articles (28.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     1 articles
#   GOOGL  (Google                        ):    25 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150611154500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 1,082 potentially relevant articles
#   ✓ Filtered from 3,979 total articles (27.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):    21 articles
# Processing 20150611214500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 831 potentially relevant articles
#   ✓ Filtered from 2,972 total articles (28.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150615113000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 734 potentially relevant articles
#   ✓ Filtered from 3,169 total articles (23.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    13 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150618024500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 493 potentially relevant articles
#   ✓ Filtered from 2,185 total articles (22.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150622104500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 716 potentially relevant articles
#   ✓ Filtered from 2,573 total articles (27.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150624151500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 943 potentially relevant articles
#   ✓ Filtered from 3,614 total articles (26.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150625230000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 760 potentially relevant articles
#   ✓ Filtered from 3,157 total articles (24.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150626000000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 650 potentially relevant articles
#   ✓ Filtered from 2,576 total articles (25.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150628183000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 399 potentially relevant articles
#   ✓ Filtered from 1,673 total articles (23.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20150706180000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 902 potentially relevant articles
#   ✓ Filtered from 4,292 total articles (21.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    17 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     3 articles
# Processing 20150706213000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 983 potentially relevant articles
#   ✓ Filtered from 4,163 total articles (23.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    11 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     6 articles
# Processing 20150708063000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 659 potentially relevant articles
#   ✓ Filtered from 2,806 total articles (23.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150711120000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 396 potentially relevant articles
#   ✓ Filtered from 1,786 total articles (22.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     1 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150712083000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 311 potentially relevant articles
#   ✓ Filtered from 1,839 total articles (16.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     4 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20150714161500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 956 potentially relevant articles
#   ✓ Filtered from 4,198 total articles (22.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    30 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     6 articles
# Processing 20150716121500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 972 potentially relevant articles
#   ✓ Filtered from 3,648 total articles (26.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    18 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     1 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20150717234500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 671 potentially relevant articles
#   ✓ Filtered from 2,802 total articles (23.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    30 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# ...
# Processing 20250930130000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 493 potentially relevant articles
#   ✓ Filtered from 1,552 total articles (31.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     4 articles
# Processing 20251002103000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 346 potentially relevant articles
#   ✓ Filtered from 1,223 total articles (28.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     9 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20251002143000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 434 potentially relevant articles
#   ✓ Filtered from 1,565 total articles (27.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     3 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     8 articles
# Processing 20251002170000.gkg.csv.zip...
# ✗ Error: 'utf-8' codec can't decode byte 0xbb in position 639: invalid start byte
# Processing 20251011220000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 183 potentially relevant articles
#   ✓ Filtered from 755 total articles (24.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20251015093000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 295 potentially relevant articles
#   ✓ Filtered from 1,075 total articles (27.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20251015110000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 312 potentially relevant articles
#   ✓ Filtered from 1,068 total articles (29.2%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20251016000000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 412 potentially relevant articles
#   ✓ Filtered from 1,782 total articles (23.1%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     3 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20251022000000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 421 potentially relevant articles
#   ✓ Filtered from 1,470 total articles (28.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    15 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20251022110000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 453 potentially relevant articles
#   ✓ Filtered from 1,420 total articles (31.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     1 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     9 articles
# Processing 20251024101500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 336 potentially relevant articles
#   ✓ Filtered from 1,254 total articles (26.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     5 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20251028141500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 546 potentially relevant articles
#   ✓ Filtered from 2,053 total articles (26.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     1 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    21 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20251029230000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 484 potentially relevant articles
#   ✓ Filtered from 1,903 total articles (25.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    32 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     4 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     2 articles
# Processing 20251030024500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 244 potentially relevant articles
#   ✓ Filtered from 1,039 total articles (23.5%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     1 articles
#   GOOGL  (Google                        ):     3 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20251105080000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 315 potentially relevant articles
#   ✓ Filtered from 1,197 total articles (26.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     1 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20251105194500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 601 potentially relevant articles
#   ✓ Filtered from 2,152 total articles (27.9%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     7 articles
# Processing 20251109060000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 136 potentially relevant articles
#   ✓ Filtered from 619 total articles (22.0%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     3 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20251110161500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 534 potentially relevant articles
#   ✓ Filtered from 1,948 total articles (27.4%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     7 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     2 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     7 articles
# Processing 20251110181500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 503 potentially relevant articles
#   ✓ Filtered from 1,886 total articles (26.7%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     8 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     1 articles
# Processing 20251114163000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 489 potentially relevant articles
#   ✓ Filtered from 1,862 total articles (26.3%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     1 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20251116231500.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 223 potentially relevant articles
#   ✓ Filtered from 899 total articles (24.8%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):    12 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles
# Processing 20251118043000.gkg.csv.zip...
#
# Filtering for insider trading relevance...
#   ✓ Found 322 potentially relevant articles
#   ✓ Filtered from 1,310 total articles (24.6%)
#   AMSC   (American Superconductor       ):     0 articles
#   NP     (Neenah                        ):     0 articles
#   EVR    (Evercore                      ):     0 articles
#   GOOGL  (Google                        ):     6 articles
#   GTXI   (GTx                           ):     0 articles
#   HLF    (Herbalife                     ):     0 articles
#   MDRX   (Veradigm                      ):     0 articles
#   ORCL   (Oracle                        ):     0 articles
#   SPPI   (Spectrum Pharmaceuticals      ):     0 articles
#   WFC    (Wells Fargo                   ):     0 articles

# %% [markdown]
# Read in Columns

# %%
combined_df.columns
combined_df.head()
# Out:
#           GKGRECORDID            DATE       SourceCommonName  \
# 0  20150219144500-213  20150219144500     digitaljournal.com
# 1  20150219144500-198  20150219144500    businessinsider.com
# 2  20150219144500-223  20150219144500              yahoo.com
# 3  20150219144500-575  20150219144500   hartlepoolmail.co.uk
# 4  20150219144500-592  20150219144500  searchenginewatch.com
#
#                                   DocumentIdentifier  \
# 0           http://www.digitaljournal.com/pr/2473413
# 1  http://www.businessinsider.com/silicon-valley-...
# 2  https://ca.finance.yahoo.com/news/u2-inspired-...
# 3  http://www.hartlepoolmail.co.uk/news/business/...
# 4  http://searchenginewatch.com/sew/how-to/239599...
#
#                                               Themes  \
# 0  TAX_FNCACT;TAX_FNCACT_MANAGERS;TAX_FNCACT_FUND...
# 1                          MANMADE_DISASTER_IMPLIED;
# 2  MEDIA_SOCIAL;TAX_WORLDFISH;TAX_WORLDFISH_TOP;P...
# 3  SOC_INNOVATION;TAX_FNCACT;TAX_FNCACT_ADVERTISE...
# 4  TAX_FNCACT;TAX_FNCACT_DESIGNER;ECON_WORLDCURRE...
#
#                                              Persons  \
# 0  brian ruby;lawrence calcano;michael g ricciard...
# 1                                                NaN
# 2         flickr peter neill;jeff bezos;rony abovitz
# 3  henry faure walker;scott gill;ashley highfield...
# 4                                        dave davies
#
#                                        Organizations  \
# 0  evercore private funds group;park hill group;h...
# 1                google;bmw;porsche;twitter;facebook
# 2                          google;facebook;microsoft
# 3                   google;mediaforce group;facebook
# 4                                             google
#
#                                               V2Tone  \
# 0  3.47129506008011,4.40587449933244,0.9345794392...
# 1  0.454840805717999,3.57374918778428,3.118908382...
# 2  1.37741046831956,3.58126721763085,2.2038567493...
# 3  5.05464480874317,5.60109289617486,0.5464480874...
# 4  0.859453993933266,2.42669362992922,1.567239635...
#
#                                                 GCAM  \
# 0  wc:664,c1.2:3,c12.1:19,c12.10:83,c12.11:2,c12....
# 1  wc:1318,c1.1:3,c1.2:12,c1.3:3,c12.1:104,c12.10...
# 2  wc:332,c1.4:1,c12.1:27,c12.10:26,c12.12:6,c12....
# 3  wc:668,c1.1:2,c1.2:6,c1.3:8,c12.1:51,c12.10:61...
# 4  wc:1843,c1.1:1,c1.2:3,c1.3:2,c1.4:1,c12.1:168,...
#
#                                           Quotations  ... Month   Day  Hour  \
# 0                                                NaN  ...   2.0  19.0  14.0
# 1                                                NaN  ...   2.0  19.0  14.0
# 2                                                NaN  ...   2.0  19.0  14.0
# 3                                                NaN  ...   2.0  19.0  14.0
# 4  197|182||ve always found Web design to be a fu...  ...   2.0  19.0  14.0
#
#    OrgCount                    PrimaryOrg  PersonCount       PrimaryPerson  \
# 0         8  evercore private funds group            5          brian ruby
# 1         5                        google            0                 NaN
# 2         3                        google            3  flickr peter neill
# 3         3                        google            4  henry faure walker
# 4         1                        google            1         dave davies
#
#   HasFinancialTheme Ticker  CompanyName
# 0              True    EVR     Evercore
# 1             False  GOOGL       Google
# 2              True  GOOGL       Google
# 3              True  GOOGL       Google
# 4              True  GOOGL       Google
#
# [5 rows x 30 columns]

# %% [markdown]
# Filter

# %% [markdown]
# Analyze

# %%
combined_df = md.analyze_company_coverage(combined_df)
ts = md.create_company_timeseries(combined_df)
print("\n" + "="*60)
print("✓ FILTERING COMPLETE!")
print("="*60)
print(f"\nDataFrames available:")
print(f"  - df: Full GKG data ({len(df):,} rows)")
print(f"  - df_companies: Filtered company data ({len(combined_df):,} rows)")
print(f"  - ts: Time series by company-date ({len(ts):,} rows)")
# Out:
#       Date Ticker CompanyName       Tone  Polarity      SourceCommonName
# 2021-02-05  GOOGL      Google -14.678899 16.513761            law360.com
# 2025-04-11  GOOGL      Google   3.991131 16.407982 securityinfowatch.com
# 2024-06-05  GOOGL      Google   4.924242 16.287879          albawaba.com
# 2019-04-09  GOOGL      Google -10.571429 16.285714     dailytrust.com.ng
# 2016-10-18    WFC Wells Fargo -10.128617 15.916399      counterpunch.org
# 2017-09-26    WFC Wells Fargo -10.968661 15.242165   wataugademocrat.com
# 2016-10-01    WFC Wells Fargo -13.043478 15.217391            iheart.com
# 2016-08-29  GOOGL      Google  -1.680672 15.126050   contacto-latino.com
# 2018-08-30  GOOGL      Google  -9.200969 15.012107            theiet.org
# 2018-09-12  GOOGL      Google  -8.000000 15.000000            eadt.co.uk
#
# ============================================================
# TIME SERIES DATA
# ============================================================
# ✓ Created time series with 2794 date-company pairs
#
# Sample:
#          Date Ticker  ArticleCount      Tone  Polarity  WordCount
# 0  2015-02-19    EVR             1  3.471295  5.340454   1.335113
# 1  2015-02-19  GOOGL            23  1.072080  5.262471   1.370790
# 2  2015-02-21  GOOGL            13 -2.116411  7.875497   0.393307
# 3  2015-02-23  GOOGL             1 -1.232666  3.697997   0.000000
# 4  2015-02-27    EVR             3 -1.264141  5.413669   2.626162
# 5  2015-02-27  GOOGL            11 -0.728092  5.214361   1.117178
# 6  2015-02-27   SPPI             1  0.863931  2.159827   0.000000
# 7  2015-02-28  GOOGL             2 -0.764322  7.433005   3.178129
# 8  2015-02-28    HLF             1 -0.990099  8.910891   0.000000
# 9  2015-02-28    WFC             3  0.316286  6.337466   0.501765
#
# ============================================================
# ✓ FILTERING COMPLETE!
# ============================================================
#
# DataFrames available:
#   - df: Full GKG data (6 rows)
#   - df_companies: Filtered company data (18,788 rows)
#   - ts: Time series by company-date (2,794 rows)

# %% [markdown]
# Save for future use

# %%
combined_df.to_csv('media_data/gkg_filtered_companies.csv', index=False)
ts.to_csv('media_data/gkg_company_timeseries.csv', index=False)
print(f"\n✓ Saved filtered data to CSV files")
# Out:
# ✓ Saved filtered data to CSV files
